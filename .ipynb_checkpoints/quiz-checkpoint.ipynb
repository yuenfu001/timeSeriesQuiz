# %%
from fbprophet import Prophet
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from matplotlib import rcParams
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("./household_power_consumption.txt", sep =";", parse_dates = {"date" : ["Date","Time"]}, infer_datetime_format=True, low_memory=False, na_values=["nan","?"], index_col = ["date"]).reset_index()
df.fillna(df.mean(),inplace=True)

# %%
df.head(5)
# Out:
#                  date  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16 17:24:00                4.216                  0.418   234.84
# 1 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2 2006-12-16 17:26:00                5.374                  0.498   233.29
# 3 2006-12-16 17:27:00                5.388                  0.502   233.74
# 4 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
df.shape
# Out:
# (2075259, 8)

# %%
df.isna().sum()
# Out:
# date                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   date                   datetime64[ns]
#  1   Global_active_power    float64
#  2   Global_reactive_power  float64
#  3   Voltage                float64
#  4   Global_intensity       float64
#  5   Sub_metering_1         float64
#  6   Sub_metering_2         float64
#  7   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 126.7 MB

# %%
df["date"] = pd.to_datetime(df["date"], infer_datetime_format=True)

# %%
df = df.set_index('date')

# %%
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# date
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# date
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# date
# 2006-12-16 17:24:00            17.0
# 2006-12-16 17:25:00            16.0
# 2006-12-16 17:26:00            17.0
# 2006-12-16 17:27:00            17.0
# 2006-12-16 17:28:00            17.0

# %%
df.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %% [markdown]
# ## Daily Upsampling

# %%
df_daily = df.resample("D").mean()

# %%
df_daily.shape
# Out:
# (1442, 7)

# %%
df_daily.reset_index()
# Out:
#            date  Global_active_power  Global_reactive_power     Voltage  \
# 0    2006-12-16             3.053475               0.088187  236.243763
# 1    2006-12-17             2.354486               0.156949  240.087028
# 2    2006-12-18             1.530435               0.112356  241.231694
# 3    2006-12-19             1.157079               0.104821  241.999313
# 4    2006-12-20             1.545658               0.111804  242.308063
# ...         ...                  ...                    ...         ...
# 1437 2010-11-22             1.417733               0.098857  240.197118
# 1438 2010-11-23             1.095511               0.095451  240.575528
# 1439 2010-11-24             1.247394               0.091986  240.030965
# 1440 2010-11-25             0.993864               0.080644  241.536257
# 1441 2010-11-26             1.178230               0.095666  240.291029
#
#       Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0            13.082828        0.000000        1.378788       12.439394
# 1             9.999028        1.411806        2.907639        9.264583
# 2             6.421667        0.738194        1.820139        9.734722
# 3             4.926389        0.582639        5.279167        4.303472
# 4             6.467361        0.000000        1.838889        9.765972
# ...                ...             ...             ...             ...
# 1437          6.014167        3.371528        1.465278        7.038889
# 1438          4.674444        1.299306        0.318056        5.285417
# 1439          5.249583        0.761111        1.977778        8.488889
# 1440          4.169444        0.747222        0.295833        3.522222
# 1441          4.956295        0.855107        0.304830        7.908947
#
# [1442 rows x 8 columns]

# %%
df_daily.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
df_daily.reset_index(inplace=True)

# %%
df_daily.dtypes
# Out:
# date    datetime64[ns]
# y              float64
# A              float64
# B              float64
# C              float64
# D              float64
# E              float64
# F              float64
# dtype: object

# %%
mapping = {'date':'ds','Global_active_power':'y', 'Global_reactive_power':'A', 'Voltage':'B',
       'Global_intensity':'C','Sub_metering_1':'D', 'Sub_metering_2':'E',
       'Sub_metering_3':'F'}
df_daily = df_daily.rename(mapping, axis=1)

# %%
df_daily.head()
# Out:
#           ds         y         A           B          C         D         E  \
# 0 2006-12-16  3.053475  0.088187  236.243763  13.082828  0.000000  1.378788
# 1 2006-12-17  2.354486  0.156949  240.087028   9.999028  1.411806  2.907639
# 2 2006-12-18  1.530435  0.112356  241.231694   6.421667  0.738194  1.820139
# 3 2006-12-19  1.157079  0.104821  241.999313   4.926389  0.582639  5.279167
# 4 2006-12-20  1.545658  0.111804  242.308063   6.467361  0.000000  1.838889
#
#            F
# 0  12.439394
# 1   9.264583
# 2   9.734722
# 3   4.303472
# 4   9.765972

# %%
df_daily.isna().sum()
# Out:
# ds    0
# y     0
# A     0
# B     0
# C     0
# D     0
# E     0
# F     0
# dtype: int64

# %%
model = Prophet()

# %%
model.add_regressor('A')
model.add_regressor('B')
model.add_regressor('C')
model.add_regressor('D')
model.add_regressor('E')
model.add_regressor('F')

# %%
#train = df_daily.iloc[0:]
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_daily, test_size=0.2, random_state=10)

# %%
#future = model.make_future_dataframe(periods=10, freq="D")
#forecast = model.predict(future)
#forecast.head()
train
# Out:
#              ds         y         A           B         C         D         E  \
# 370  2007-12-21  1.376789  0.073937  242.881632  5.713750  0.827083  0.138889
# 593  2008-07-31  0.967110  0.169081  240.095674  4.231806  1.064583  1.950000
# 1064 2009-11-14  1.778094  0.170728  240.222403  7.453472  2.895139  1.674306
# 139  2007-05-04  0.693144  0.121347  235.710194  3.078056  1.568750  0.373611
# 271  2007-09-13  0.796099  0.115249  239.309833  3.464444  0.815972  1.752083
# ...         ...       ...       ...         ...       ...       ...       ...
# 1393 2010-10-09  1.119292  0.176403  240.198437  4.740972  0.665972  1.100694
# 1344 2010-08-21  1.091615  0.123714  240.839858  4.627759  1.121923  1.298520
# 527  2008-05-26  0.895632  0.153262  240.363688  3.929722  0.684028  0.462500
# 1149 2010-02-07  1.128964  0.112824  242.684472  4.726806  1.900000  2.664583
# 1289 2010-06-27  0.791642  0.211604  239.947479  3.485278  1.850694  0.530556
#
#               F
# 370    8.507639
# 593    5.269444
# 1064  13.102778
# 139    2.770833
# 271    2.675694
# ...         ...
# 1393   9.119444
# 1344   6.458447
# 527    6.447222
# 1149   3.851389
# 1289   5.340278
#
# [1153 rows x 8 columns]

# %%
train.columns
# Out:
# Index(['ds', 'y', 'A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
print(train.shape)
print(test.shape)
# Out:
# (1153, 8)
# (289, 8)

# %%
model.fit(train)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.predict(test)

# %%
future.shape
# Out:
# (289, 40)

# %%
future
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   
# 286 -0.000060  0.000782  0.000782  0.000782        0.327186
# 287  0.000414 -0.001758 -0.001758 -0.001758        0.008639
# 288  0.000420  0.002042  0.002042  0.002042        0.081446
#
#      additive_terms_lower  additive_terms_upper  extra_regressors_additive  \
# 0                2.247842              2.247842                   2.238309
# 1               -0.013511             -0.013511                  -0.022624
# 2                0.787268              0.787268                   0.779517
# 3               -0.078670             -0.078670                  -0.082456
# 4                1.021876              1.021876                   1.019173
# ..                    ...                   ...                        ...
# 284             -0.006647             -0.006647                  -0.010420
# 285              0.439031              0.439031                   0.434770
# 286              0.327186              0.327186                   0.323358
# 287              0.008639              0.008639                   0.006258
# 288              0.081446              0.081446                   0.077103
#
#      extra_regressors_additive_lower  extra_regressors_additive_upper  \
# 0                           2.238309                         2.238309
# 1                          -0.022624                        -0.022624
# 2                           0.779517                         0.779517
# 3                          -0.082456                        -0.082456
# 4                           1.019173                         1.019173
# ..                               ...                              ...
# 284                        -0.010420                        -0.010420
# 285                         0.434770                         0.434770
# 286                         0.323358                         0.323358
# 287                         0.006258                         0.006258
# 288                         0.077103                         0.077103
#
#        weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 0    0.000619      0.000619      0.000619  0.008914      0.008914
# 1    0.000249      0.000249      0.000249  0.008863      0.008863
# 2   -0.000024     -0.000024     -0.000024  0.007775      0.007775
# 3    0.000266      0.000266      0.000266  0.003519      0.003519
# 4   -0.000177     -0.000177     -0.000177  0.002881      0.002881
# ..        ...           ...           ...       ...           ...
# 284  0.000266      0.000266      0.000266  0.003507      0.003507
# 285  0.000619      0.000619      0.000619  0.003643      0.003643
# 286 -0.000024     -0.000024     -0.000024  0.003851      0.003851
# 287 -0.001546     -0.001546     -0.001546  0.003927      0.003927
# 288  0.000266      0.000266      0.000266  0.004076      0.004076
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        0.008914                   0.0                         0.0
# 1        0.008863                   0.0                         0.0
# 2        0.007775                   0.0                         0.0
# 3        0.003519                   0.0                         0.0
# 4        0.002881                   0.0                         0.0
# ..            ...                   ...                         ...
# 284      0.003507                   0.0                         0.0
# 285      0.003643                   0.0                         0.0
# 286      0.003851                   0.0                         0.0
# 287      0.003927                   0.0                         0.0
# 288      0.004076                   0.0                         0.0
#
#      multiplicative_terms_upper      yhat
# 0                           0.0  3.334230
# 1                           0.0  1.073502
# 2                           0.0  1.875063
# 3                           0.0  1.010844
# 4                           0.0  2.111703
# ..                          ...       ...
# 284                         0.0  1.093728
# 285                         0.0  1.539394
# 286                         0.0  1.427526
# 287                         0.0  1.108968
# 288                         0.0  1.181740
#
# [289 rows x 40 columns]

# %%
from sklearn.metrics import mean_squared_error as MSE, mean_absolute_percentage_error as MAPE

# %%
Y = np.array(test["y"])
Y_pred = np.array(future["yhat"])

mape = MAPE(Y, Y_pred)

mape
# Out:
# 0.5694227090287888

# %%
rmse = np.sqrt(MSE(Y,Y_pred)) 
rmse
# Out:
# 0.6166736793307109

# %%
model.plot(future)

# %%
rcParams["figure.figsize"] = (30,10)
model.plot(forecast)
plt.show()
